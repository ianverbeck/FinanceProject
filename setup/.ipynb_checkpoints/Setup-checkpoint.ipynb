# %%
import sqlite3

import pandas as pd
import numpy as np
from urllib.request import urlopen  
import json

getkey = ! cat ../../apikey.txt
apikey = getkey[0]

from Resources.fhelp import get_appended, get_appended2

# %%
#get list of tickers (just dow until everything is set up)
dow_url = "https://financialmodelingprep.com/api/v3/dowjones_constituent?apikey=600e501fe324b2f1cbb2aec5b390b6db"
dow_tick = pd.read_json(dow_url)
tickers = list(dow_tick.symbol.values)
print(tickers,)
tickers += ['SECO']
# Out:
# ['CRM', 'WBA', 'V', 'NKE', 'UNH', 'TRV', 'VZ', 'INTC', 'WMT', 'JNJ', 'DIS', 'MCD', 'JPM', 'CAT', 'BA', 'AMGN', 'DOW', 'AAPL', 'GS', 'CSCO', 'MSFT', 'HD', 'PG', 'MRK', 'IBM', 'HON', 'KO', 'CVX', 'AXP', 'MMM']

# %%
urls = pd.read_json('Resources/urls.json',typ='series')

# %%
conn = sqlite3.connect('../../Finances.db')
c = conn.cursor()

# %%
tickers = ['AAPL']

# %%
schemas = open("schema.sql", "a+")
for name, url in zip(urls.index,urls.values):
    print(name)
    if url =='NONE':
            continue
    if type(url) != dict:
        tab = get_appended2(url,tickers,apikey,verbose=False)
        tab.drop_duplicates(inplace=True)
        a = pd.io.sql.get_schema(tab,name)
        c.execute('drop table if exists '+ name)
        c.execute(a)
        tosql = a +';\n\n'
        schemas.write(tosql)
        tab.to_sql(name,con=conn,index=False,if_exists='append')
    else: 
        for i, u in enumerate(url.values()):
            print(u)
            if i == 1: 
                tab = get_appended2(u,tickers,apikey,verbose=True)
                tab.drop_duplicates(inplace=True)
                a = pd.io.sql.get_schema(tab,name)
                c.execute('drop table if exists '+ name)
                c.execute(a)
                tosql = a +';\n\n'
                schemas.write(tosql)
                tab.to_sql(name,con=conn,index=False,if_exists='append')
                print(c.execute('select * from '+name+' limit 1;').fetchall())
            else:
                tab= get_appended2(u,tickers,apikey,verbose=True)
                tab.drop_duplicates(inplace=True)
                tab.to_sql(name,con=conn,index=False,if_exists='append')
# Out:
# CV_PROFILE
# CV_QUOTE
# CV_EXECUTIVES
# NAMER-------------
# AAPL
# CV_SEARCH
# CV_FS_INCOME_YR
# CV_FS_INCOME_QTR
# CV_FS_BALANCESHEET_YR
# CV_FS_BALANCESHEET_QTR
# CV_FS_CASHFLOW_YR
# CV_FS_CASHFLOW_QTR
# CV_FS_INCOMEGROWTH_YR
# CV_FS_BALANCEGROWTH_YR
# CV_FS_CASHGROWTH_YR
# CV_INTLFILINGS
# CV_FS_ASREPORTED
# CV_RATIOS_TTM
# NAMER-------------
# AAPL
# CV_RATIOS_YR
# CV_RATIOS_QTR
# CV_ENTERPRISEVALUE_YR
# CV_ENTERPRISEVALUE_QTR
# CV_METRICS_TTM
# NAMER-------------
# AAPL
# CV_METRICS_YR
# CV_METRICS_QTR
# CV_GROWTH_YR
# CV_GROWTH_QTR
# CV_RATING
# CV_RATING_DAY
# CV_DCF
# /Users/verbeck/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   if __name__ == '__main__':
# /Users/verbeck/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:2663: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,
# CV_DCF_YR
# IGASKJB AAPL
# NAMER-------------
# AAPL
# CV_DCF_QTR
# IGASKJB AAPL
# NAMER-------------
# AAPL
# CV_DCF_DAY
# CV_MARKETCAP
# CV_MARKETCAP_DAY
# CV_SYMBOLS
# CV_ETFS
# CV_TRADABLE
# CV_BATCHREQUEST
# CV_STOCKSCREENER
# CV_DELISTED
# CV_NEWS
# CV_EARNINGSCALLTRANSCRIPT
# CV_EARNINGSSURPRISES
# CV_SECFILINGS
# C_PRESSRELEASES
# INS_STOCKTRADING
# INS_RSSFEED
# CAL_EARNINGSCALENDAR_UPC
# CAL_EARNINGSCALENDAR_HIST
# CAL_IPO
# CAL_SPLITS
# CAL_DIVIDENDS
# CAL_ECONOMIC
# INST_HOLDERS
# NAMER-------------
# AAPL
# INST_MUTFUNDHOLDERS
# NAMER-------------
# AAPL
# INST_ETFHOLDERS
# NAMER-------------
# AAPL
# INST_ETFSECTORWEIGHTS
# NAMER-------------
# AAPL
# INST_ETFCOUNTRYWEIGHTS
# NAMER-------------
# AAPL
# INST_SECRSSFEED
# INST_13F
# TS_PRICE
# TS_PRICELIST
# TS_PRICE_DAY
# UYJFDKJB AAPL
# NAMER-------------
# AAPL
# TS_DIVIDENDS_HIST
# UYJFDKJB AAPL
# NAMER-------------
# AAPL
# TS_SPLITS_HIST
# UYJFDKJB AAPL
# NAMER-------------
# AAPL
# TS_BIASFREE
# TI_DAILY
# TI_INTRADAY
# MI_MAJORINDEXES
# MI_SP500LIST
# MI_SP500HIST
# MI_NASDAQLIST
# MI_NASDAQHISTLIST
# MI_DOWJLIST
# MI_DOWJHISTLIST
# MI_INDEXPRICEHIST_DAY
# https://financialmodelingprep.com/api/v3/historical-price-full/%5EGSPC?apikey=
# Downloading for ticker AAPL....
# UYJFDKJB ^GSPC
# NAMER-------------
# ^GSPC
#             date         open         high          low        close  \
# 0     2021-02-12  3911.649902  3937.229980  3905.780029  3934.830078
# 1     2021-02-11  3916.399902  3925.989990  3890.389893  3916.379883
# 2     2021-02-10  3920.780029  3931.500000  3884.939941  3909.879883
# 3     2021-02-09  3910.489990  3918.350098  3902.639893  3911.229980
# 4     2021-02-08  3892.590088  3915.770020  3892.590088  3915.590088
# ...          ...          ...          ...          ...          ...
# 1254  2016-02-22  1924.439941  1946.699951  1924.439941  1945.500000
# 1255  2016-02-19  1916.739990  1918.780029  1902.170044  1917.780029
# 1256  2016-02-18  1927.569946  1930.000000  1915.089966  1917.829956
# 1257  2016-02-17  1898.800049  1930.680054  1898.800049  1926.819946
# 1258  2016-02-16  1871.439941  1895.770020  1871.439941  1895.579956
# 1255  16391.990234  134340000.0       134340000.0  -18.97070         -0.116
# 1256  16413.429688  104950000.0       104950000.0  -70.33008         -0.427
# 1257  16453.830078  124080000.0       124080000.0  235.84961          1.454
# 1258  16196.410156  142030000.0       142030000.0  184.02051          1.149
#
#              vwap            label  changeOverTime symbol
# 0     31427.17057  February 12, 21         0.00120   ^DJI
# 1     31406.29297  February 11, 21        -0.00114   ^DJI
# 2     31390.18685  February 10, 21         0.00031   ^DJI
# 3     31353.72005  February 09, 21         0.00051   ^DJI
# 4     31321.01953  February 08, 21         0.00624   ^DJI
# ...           ...              ...             ...    ...
# 1254  16567.34375  February 22, 16         0.01240   ^DJI
# 1255  16360.31706  February 19, 16        -0.00116   ^DJI
# 1256  16438.56641  February 18, 16        -0.00427   ^DJI
# 1257  16385.97656  February 17, 16         0.01454   ^DJI
# 1258  16135.06999  February 16, 16         0.01149   ^DJI
#
# [1259 rows x 14 columns]

# %%
# Out:
# 'CREATE TABLE "CV_EXECUTIVES" (\n\n)'

# %%
u = urls['TS_PRICE_DAY']
uu = u.replace(' ','AAPL') + apikey
output = json.load(urlopen(uu))
norm = pd.read_json(uu)
display(norm)
norm.shape

# %%
ttdf =  pd.DataFrame()
for i in range(len(norm)):
    ttdf = ttdf.append(pd.Series(norm.iloc[i,1]),ignore_index=True)

# %%
norm.loc[:,'Series'] = pd.Series(norm.iloc[:,1])

# %%
ser = pd.Series(norm.iloc[:,1])

# %%
u = urls['TS_PRICE_DAY']
uu = u.replace(' ','AAPL') + apikey
output = json.load(urlopen(uu))
norm = pd.read_json(uu)

# %%
pd.read_json(json.dumps(pd.read_json(uu).iloc[0,1]))

# %%
ttdf = pd.read_json(uu)
print(ttdf)
            
if ttdf.shape == (1,2):
    print(ttdf)
    ttdf = pd.read_json(json.dumps(pd.read_json(uu).iloc[0,1]))
    print(ttdf)

# %%
norm['historical'] = norm['historical'].apply(lambda x: pd.Series(x))

# %%
indexp = urls['MI_INDEXPRICEHIST_DAY']

# %%
for i in indexp:
    print(pd.read_json(indexp[i]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-94cd10e84715> in <module>
#       1 for i in indexp:
# ----> 2     print(pd.read_json(indexp[i]))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     606         return json_reader
#     607
# --> 608     result = json_reader.read()
#     609     if should_close:
#     610         filepath_or_buffer.close()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in read(self)
#     729             obj = self._get_object_parser(self._combine_lines(data.split("\n")))
#     730         else:
# --> 731             obj = self._get_object_parser(self.data)
#     732         self.close()
#     733         return obj
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in _get_object_parser(self, json)
#     751         obj = None
#     752         if typ == "frame":
# --> 753             obj = FrameParser(json, **kwargs).parse()
#     754
#     755         if typ == "series" or obj is None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in parse(self)
#     855
#     856         else:
# --> 857             self._parse_no_numpy()
#     858
#     859         if self.obj is None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in _parse_no_numpy(self)
#    1087         if orient == "columns":
#    1088             self.obj = DataFrame(
# -> 1089                 loads(json, precise_float=self.precise_float), dtype=None
#    1090             )
#    1091         elif orient == "split":
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      62     # figure out the index, if necessary
#      63     if index is None:
# ---> 64         index = extract_index(arrays)
#      65     else:
#      66         index = ensure_index(index)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     353
#     354         if not indexes and not raw_lengths:
# --> 355             raise ValueError("If using all scalar values, you must pass an index")
#     356
#     357         if have_series:
#
# ValueError: If using all scalar values, you must pass an index

# %%
pd.read_json(indexp[i]+apikey)
# Out:
#      symbol                                         historical
# 0     ^GSPC  {'date': '2021-02-12', 'open': 3911.649902, 'h...
# 1     ^GSPC  {'date': '2021-02-11', 'open': 3916.399902, 'h...
# 2     ^GSPC  {'date': '2021-02-10', 'open': 3920.780029, 'h...
# 3     ^GSPC  {'date': '2021-02-09', 'open': 3910.48999, 'hi...
# 4     ^GSPC  {'date': '2021-02-08', 'open': 3892.590088, 'h...
# ...     ...                                                ...
# 1254  ^GSPC  {'date': '2016-02-22', 'open': 1924.439941, 'h...
# 1255  ^GSPC  {'date': '2016-02-19', 'open': 1916.73999, 'hi...
# 1256  ^GSPC  {'date': '2016-02-18', 'open': 1927.569946, 'h...
# 1257  ^GSPC  {'date': '2016-02-17', 'open': 1898.800049, 'h...
# 1258  ^GSPC  {'date': '2016-02-16', 'open': 1871.439941, 'h...
#
# [1259 rows x 2 columns]

# %%
pd.DataFrame(indexp).iloc[0:,] + apikey
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-0751d7399dcb> in <module>
# ----> 1 pd.DataFrame(indexp).iloc[0:,] + apikey
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      62     # figure out the index, if necessary
#      63     if index is None:
# ---> 64         index = extract_index(arrays)
#      65     else:
#      66         index = ensure_index(index)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     353
#     354         if not indexes and not raw_lengths:
# --> 355             raise ValueError("If using all scalar values, you must pass an index")
#     356
#     357         if have_series:
#
# ValueError: If using all scalar values, you must pass an index

# %%
a2 = pd.DataFrame()
a = pd.Series(data=indexp)
for i in range(3):
    print(a.iloc[i]+apikey)
    try:
        print(pd.read_json(a.iloc[i]+apikey))
    except Exception as e:
        print('Failed')
# Out:
# https://financialmodelingprep.com/api/v3/historical-price-full/%5EGSPC?apikey=600e501fe324b2f1cbb2aec5b390b6db
#      symbol                                         historical
# 0     ^GSPC  {'date': '2021-02-12', 'open': 3911.649902, 'h...
# 1     ^GSPC  {'date': '2021-02-11', 'open': 3916.399902, 'h...
# 2     ^GSPC  {'date': '2021-02-10', 'open': 3920.780029, 'h...
# 3     ^GSPC  {'date': '2021-02-09', 'open': 3910.48999, 'hi...
# 4     ^GSPC  {'date': '2021-02-08', 'open': 3892.590088, 'h...
# ...     ...                                                ...
# 1254  ^GSPC  {'date': '2016-02-22', 'open': 1924.439941, 'h...
# 1255  ^GSPC  {'date': '2016-02-19', 'open': 1916.73999, 'hi...
# 1256  ^GSPC  {'date': '2016-02-18', 'open': 1927.569946, 'h...
# 1257  ^GSPC  {'date': '2016-02-17', 'open': 1898.800049, 'h...
# 1258  ^GSPC  {'date': '2016-02-16', 'open': 1871.439941, 'h...
#
# [1259 rows x 2 columns]
# https://financialmodelingprep.com/api/v3/historical-price-full/%5EIXIC?apikey=600e501fe324b2f1cbb2aec5b390b6db
#      symbol                                         historical
# 0     ^IXIC  {'date': '2021-02-12', 'open': 13979.209961, '...
# 1     ^IXIC  {'date': '2021-02-11', 'open': 14045.209961, '...
# 2     ^IXIC  {'date': '2021-02-10', 'open': 14093.349609, '...
# 3     ^IXIC  {'date': '2021-02-09', 'open': 13966.820313, '...
# 4     ^IXIC  {'date': '2021-02-08', 'open': 13937.05957, 'h...
# ...     ...                                                ...
# 1254  ^IXIC  {'date': '2016-02-22', 'open': 4548.310059, 'h...
# 1255  ^IXIC  {'date': '2016-02-19', 'open': 4464.669922, 'h...
# 1256  ^IXIC  {'date': '2016-02-18', 'open': 4548.100098, 'h...
# 1257  ^IXIC  {'date': '2016-02-17', 'open': 4471.660156, 'h...
# 1258  ^IXIC  {'date': '2016-02-16', 'open': 4397.950195, 'h...
#
# [1259 rows x 2 columns]
# https://financialmodelingprep.com/api/v3/historical-price-full/%5DJI?apikey=600e501fe324b2f1cbb2aec5b390b6db
# Empty DataFrame
# Columns: []
# Index: []
